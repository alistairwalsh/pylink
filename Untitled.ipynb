# %%
import pandas as pd

# %%
ls /Users/Neuromancer/style/
# Out:
# images/             style-notebook.css  style-table.css     style.py

# %%
# %load /Users/Neuromancer/style/style.py
from IPython.core.display import HTML
css = open('/Users/Neuromancer/style/style-table.css').read() + open('/Users/Neuromancer/style/style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %% [markdown]
# ### The hello

# %%
# !ls ../2016-03-31-Net_promoter_score/
# Out:
# 2016-03-31-Net_Promoter_Score_Responses.csv
# response_analysis.ipynb

# %%
data1 = pd.read_csv('../2016-03-31-Net_promoter_score/2016-03-31-Net_Promoter_Score_Responses.csv')

# %%
data1
# Out:
#              Timestamp       What training have you just attended?  \
# 0                  NaN                                         NaN
# 1   3/31/2016 14:30:20  Programming and data analysis using Matlab
# 2   3/31/2016 14:31:49  Programming and data analysis using Matlab
# 3   3/31/2016 14:32:49  Programming and data analysis using Matlab
# 4   3/31/2016 14:33:18  Programming and data analysis using Matlab
# 5   3/31/2016 14:33:39  Programming and data analysis using Matlab
# 6   3/31/2016 14:33:51  Programming and data analysis using Matlab
# 7   3/31/2016 14:34:15  Programming and data analysis using Matlab
# 8   3/31/2016 14:35:24  Programming and data analysis using Matlab
# 9   3/31/2016 14:35:38  Programming and data analysis using Matlab
# 10  3/31/2016 14:36:10  Programming and data analysis using Matlab
# 11  3/31/2016 14:39:26  Programming and data analysis using Matlab
# 12  3/31/2016 14:49:50  Programming and data analysis using Python
# ...

# %%
data1.T
# Out:
#                                                      0   \
# Timestamp                                           NaN
# What training have you just attended?               NaN
# How likely are you to recommend this training t...  NaN
# If there is something you could change about th...  NaN
#
#                                                                                                    1   \
# Timestamp                                                                          3/31/2016 14:30:20
# What training have you just attended?                      Programming and data analysis using Matlab
# How likely are you to recommend this training t...                                                  9
# If there is something you could change about th...  First day could have been about an hour shorte...
#
#                                                                                                    2   \
# ...

# %%
data2 = data1.set_index(['How likely are you to recommend this training to a friend or colleague?','What training have you just attended?'])

# %%
data3 = data2.T

# %%
data2
# Out:
#                                                                                                         Timestamp  \
# How likely are you to recommend this training t... What training have you just attended?
# NaN                                                NaN                                                        NaN
# 9                                                  Programming and data analysis using Matlab  3/31/2016 14:30:20
# 10                                                 Programming and data analysis using Matlab  3/31/2016 14:31:49
# 9                                                  Programming and data analysis using Matlab  3/31/2016 14:32:49
# 8                                                  Programming and data analysis using Matlab  3/31/2016 14:33:18
# 7                                                  Programming and data analysis using Matlab  3/31/2016 14:33:39
# ...

# %%
data3.T
# Out:
#                                                                                                         Timestamp  \
# How likely are you to recommend this training t... What training have you just attended?
# NaN                                                NaN                                                        NaN
# 9                                                  Programming and data analysis using Matlab  3/31/2016 14:30:20
# 10                                                 Programming and data analysis using Matlab  3/31/2016 14:31:49
# 9                                                  Programming and data analysis using Matlab  3/31/2016 14:32:49
# 8                                                  Programming and data analysis using Matlab  3/31/2016 14:33:18
# 7                                                  Programming and data analysis using Matlab  3/31/2016 14:33:39
# ...
